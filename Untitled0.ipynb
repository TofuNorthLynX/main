# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')
# gs = pd.read_csv('gender_submission.csv') 

df = pd.concat([df1, df2], ignore_index=True)

df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1 = df1.drop('Name', axis=1)
df1 = df1.drop('Ticket', axis=1)
df1 = df1.drop('Cabin', axis=1)
df2 = df2.drop('Name', axis=1)
df2 = df2.drop('Ticket', axis=1)
df2 = df2.drop('Cabin', axis=1)
df2 = df2.drop('Embarked', axis=1)

# %%
df1.head(20)
# Out:
#     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0             1         0       3    male  22.0      1      0   7.2500
# 1             2         1       1  female  38.0      1      0  71.2833
# 2             3         1       3  female  26.0      0      0   7.9250
# 3             4         1       1  female  35.0      1      0  53.1000
# 4             5         0       3    male  35.0      0      0   8.0500
# 5             6         0       3    male   NaN      0      0   8.4583
# 6             7         0       1    male  54.0      0      0  51.8625
# 7             8         0       3    male   2.0      3      1  21.0750
# 8             9         1       3  female  27.0      0      2  11.1333
# 9            10         1       2  female  14.0      1      0  30.0708
# 10           11         1       3  female   4.0      1      1  16.7000
# 11           12         1       1  female  58.0      0      0  26.5500
# ...

# %%
df2.head(20)
# Out:
#     PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare
# 0           892       3    male  34.5      0      0   7.8292
# 1           893       3  female  47.0      1      0   7.0000
# 2           894       2    male  62.0      0      0   9.6875
# 3           895       3    male  27.0      0      0   8.6625
# 4           896       3  female  22.0      1      1  12.2875
# 5           897       3    male  14.0      0      0   9.2250
# 6           898       3  female  30.0      0      0   7.6292
# 7           899       2    male  26.0      1      1  29.0000
# 8           900       3  female  18.0      0      0   7.2292
# 9           901       3    male  21.0      2      0  24.1500
# 10          902       3    male   NaN      0      0   7.8958
# 11          903       1    male  46.0      0      0  26.0000
# 12          904       1  female  23.0      1      0  82.2667
# 13          905       2    male  63.0      1      0  26.0000
# ...

# %%
rows = len(df1.axes[0])
cols = len(df1.axes[1])

rows2 = len(df2.axes[0])
cols2 = len(df2.axes[1])

print("Тренировочный:")
print("строки: " + str(rows))
print("столбцы: " + str(cols))
print(" ")
print("Тестовый:")
print("строки: " + str(rows2))
print("столбцы: " + str(cols2))
# Out:
# Тренировочный:
# строки: 891
# столбцы: 9
#
# Тестовый:
# строки: 418
# столбцы: 7

# %%
df1.info()
print(" ")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    object
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# dtype: int64

# %%
df1.groupby('Sex')['PassengerId'].count()
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
df2.groupby('Sex')['PassengerId'].count()
# Out:
# Sex
# female    152
# male      266
# Name: PassengerId, dtype: int64

# %%
df1.groupby('Pclass')['PassengerId'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64

# %%
df2.groupby('Pclass')['PassengerId'].count()
# Out:
# Pclass
# 1    107
# 2     93
# 3    218
# Name: PassengerId, dtype: int64

# %%
X = pd.get_dummies(df1)
X.head(10)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# 0            1         0       3  22.0      1      0   7.2500           0
# 1            2         1       1  38.0      1      0  71.2833           1
# 2            3         1       3  26.0      0      0   7.9250           1
# 3            4         1       1  35.0      1      0  53.1000           1
# 4            5         0       3  35.0      0      0   8.0500           0
# 5            6         0       3   NaN      0      0   8.4583           0
# 6            7         0       1  54.0      0      0  51.8625           0
# 7            8         0       3   2.0      3      1  21.0750           0
# 8            9         1       3  27.0      0      2  11.1333           1
# 9           10         1       2  14.0      1      0  30.0708           1
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         1           0           0           1
# 1         0           1           0           0
# ...

# %%
X2 = pd.get_dummies(df2)
X2.head(10)
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male
# 0          892       3  34.5      0      0   7.8292           0         1
# 1          893       3  47.0      1      0   7.0000           1         0
# 2          894       2  62.0      0      0   9.6875           0         1
# 3          895       3  27.0      0      0   8.6625           0         1
# 4          896       3  22.0      1      1  12.2875           1         0
# 5          897       3  14.0      0      0   9.2250           0         1
# 6          898       3  30.0      0      0   7.6292           1         0
# 7          899       2  26.0      1      1  29.0000           0         1
# 8          900       3  18.0      0      0   7.2292           1         0
# 9          901       3  21.0      2      0  24.1500           0         1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
X.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Sex_female   891 non-null    uint8
#  8   Sex_male     891 non-null    uint8
#  9   Embarked_C   891 non-null    uint8
#  10  Embarked_Q   891 non-null    uint8
#  11  Embarked_S   891 non-null    uint8
# dtypes: float64(2), int64(5), uint8(5)
# memory usage: 53.2 KB

# %%
X2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Age          332 non-null    float64
#  3   SibSp        418 non-null    int64
#  4   Parch        418 non-null    int64
#  5   Fare         417 non-null    float64
#  6   Sex_female   418 non-null    uint8
#  7   Sex_male     418 non-null    uint8
# dtypes: float64(2), int64(4), uint8(2)
# memory usage: 20.5 KB

# %%
print(X['Survived'].corr(X['Pclass']))
print(X['Survived'].corr(X['Age']))
print(X['Survived'].corr(X['SibSp']))
print(X['Survived'].corr(X['Parch']))
print(X['Survived'].corr(X['Fare']))
print(X['Survived'].corr(X['Sex_male']))
print(X['Survived'].corr(X['Sex_female']))
# Out:
# -0.3384810359610148
# -0.07722109457217768
# -0.03532249888573564
# 0.08162940708348371
# 0.2573065223849625
# -0.5433513806577555
# 0.5433513806577555

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot = True, annot_kws={'size':14})
sns.set_style('white')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
# %matplotlib inline
plt.figure()
plt.bar(X['Age'],X['Survived'], ec = 'black', color = '#12345b')
plt.xlabel('Зависимость Age к Survived')
plt.show()

plt.figure()
plt.bar(X['Pclass'],X['Survived'], ec = 'black', color = '#12345b')
plt.xlabel('Зависимость Pclass к Survived')
plt.show()

plt.figure()
plt.bar(X['SibSp'],X['Survived'], ec = 'black', color = '#12345b')
plt.xlabel('Зависимость SibSp к Survived')
plt.show()

plt.figure()
plt.bar(X['Parch'],X['Survived'], ec = 'black', color = '#12345b')
plt.xlabel('Зависимость Parch к Survived')
plt.show()

plt.figure()
plt.bar(X['Fare'],X['Survived'], ec = 'black', color = '#12345b')
plt.xlabel('Зависимость Fare к Survived')
plt.show()

# %%
y = np.array(X['Survived'])
x = np.array(X['Age']).reshape(-1,1)
model = LinearRegression()
model.fit(x,y)
print('coef:',model.coef_)
print('score',model.score(x,y))
plt.scatter(X['anchor_ratio'],X['ale'], color = '#12345b')
plt.plot(x,model.predict(x))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-67243e10e06f> in <module>
#       3 model = LinearRegression()
#       4
# ----> 5 print('coef:',model.coef_)
#       6 print('score',model.score(x,y))
#       7 plt.scatter(X['anchor_ratio'],X['ale'], color = '#12345b')
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'
